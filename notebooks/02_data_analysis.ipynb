# %% [markdown]
# # Phase 2: Data Analysis
#
# In this notebook, we will perform initial exploratory data analysis (EDA) on the Predictive Maintenance Dataset.

# %%
import pandas as pd

# Step 14: Dataset Load Karo
df = pd.read_csv("../datasets/predictive_maintenance.csv")

# Step 15: Samajho .head()
df.head()

# %%
# Step 16: Shape Dekho
print("Dataset Shape:", df.shape)

# %%
# Step 17: Columns Dekho
print("Columns:", df.columns)

# %%
# Step 18: Data Types Check
df.info()

# %%
# Step 19: Statistics Samjho
df.describe()

# %%
# Step 20: Missing Values Check
print("Missing Values:\n", df.isnull().sum())

# %%
# Step 21: Basic Visualization
import matplotlib.pyplot as plt

try:
    df["Air temperature"].hist()
    plt.title("Air Temperature Distribution")
    plt.show()
except KeyError:
    print("Column not found. Available columns are:", df.columns)
